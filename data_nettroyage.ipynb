# %%
import pandas as pd

# Replace 'your_file.csv' with the actual path to your CSV file
file_path = '15topics.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
df[df['topic']=='Politics']
# Out:
#         topic           hashtag  \
# 0    Politics  NationalPolitics
# 1    Politics  NationalPolitics
# 2    Politics  NationalPolitics
# 3    Politics  NationalPolitics
# 4    Politics  NationalPolitics
# ..        ...               ...
# 117  Politics    ForeignAffairs
# 118  Politics    ForeignAffairs
# 119  Politics    ForeignAffairs
# 120  Politics   LocalGovernance
# 121  Politics   LocalGovernance
#
#                                                content hashtag_related 1  \
# 0    Now, a member of Minnesota's Congressional del...         #Business
# 1    Markus Söder’s crumbling empire https://www.po...               NaN
# 2    Poland, Hungary, Slovakia impose own Ukraine g...               NaN
# 3    Vienna seeks to calm Selmayr ‘blood money’ fur...               NaN
# 4    Brexiters rage after crowd waves EU flags at R...               NaN
# ..                                                 ...               ...
# 117  Erdoğan cancels Granada summit trip after fall...               NaN
# 118  From political hashtags to social media use: #...       #DigitalAge
# 119  EU, US and Russia held secret talks days befor...               NaN
# 120  The Lib Dems have recently taken over from thi...           #surrey
# 121  # உள்ளாட்சி_தினம் : இன்று நகர சபை கூட்டங்களை த...  #உள்ளாட்சி_தினம்
#
#         hashtag_related 2 hashtag_related 3   hashtag_related 4  \
# 0                 #Hudson        #UAWStrike                 NaN
# 1                     NaN               NaN                 NaN
# 2                     NaN               NaN                 NaN
# 3                     NaN               NaN                 NaN
# 4                     NaN               NaN                 NaN
# ..                    ...               ...                 ...
# 117                   NaN               NaN                 NaN
# 118  #CrisisCommunication             #GIGA               #DSLS
# 119                   NaN               NaN                 NaN
# 120      #localgovernance  #localgovernment  #torymismanagement
# 121       #LocalBodiesDay        #AreaSabha           #meetings
#
#     hashtag_related 5           author                         create_at
# 0                 NaN           strike         2023-10-06 11:52:06+00:00
# 1                 NaN  politico_eu_bot  2023-10-06 02:18:11.689000+00:00
# 2                 NaN  politico_eu_bot  2023-09-16 09:34:38.494000+00:00
# 3                 NaN  politico_eu_bot  2023-09-10 17:33:43.008000+00:00
# 4                 NaN  politico_eu_bot  2023-09-10 15:13:45.314000+00:00
# ..                ...              ...                               ...
# 117               NaN  politico_eu_bot  2023-10-04 14:27:57.169000+00:00
# 118         #DigiTraL   GIGA_Institute         2023-10-04 08:39:17+00:00
# 119               NaN  politico_eu_bot  2023-10-04 02:07:40.570000+00:00
# 120       #ukpolitics     larleywilson         2023-02-25 09:17:03+00:00
# 121               NaN   patrikaidotcom         2022-11-01 05:05:18+00:00
#
# [122 rows x 10 columns]

# %%
from langdetect import detect
def is_english(text):
    try:
        return detect(text) == 'en'
    except:
        # 处理无法检测语言的情况
        return False
df = df[df['content'].apply(is_english)]
df[df['topic']=='Politics']
# Out:
#         topic           hashtag  \
# 0    Politics  NationalPolitics
# 2    Politics  NationalPolitics
# 3    Politics  NationalPolitics
# 4    Politics  NationalPolitics
# 5    Politics  NationalPolitics
# ..        ...               ...
# 116  Politics    ForeignAffairs
# 117  Politics    ForeignAffairs
# 118  Politics    ForeignAffairs
# 119  Politics    ForeignAffairs
# 120  Politics   LocalGovernance
#
#                                                content hashtag_related 1  \
# 0    Now, a member of Minnesota's Congressional del...         #Business
# 2    Poland, Hungary, Slovakia impose own Ukraine g...               NaN
# 3    Vienna seeks to calm Selmayr ‘blood money’ fur...               NaN
# 4    Brexiters rage after crowd waves EU flags at R...               NaN
# 5    UK’s Sunak raises ‘strong concerns’ over alleg...               NaN
# ..                                                 ...               ...
# 116  Don’t expect EU sanctions on Azerbaijan — even...               NaN
# 117  Erdoğan cancels Granada summit trip after fall...               NaN
# 118  From political hashtags to social media use: #...       #DigitalAge
# 119  EU, US and Russia held secret talks days befor...               NaN
# 120  The Lib Dems have recently taken over from thi...           #surrey
#
#         hashtag_related 2 hashtag_related 3   hashtag_related 4  \
# 0                 #Hudson        #UAWStrike                 NaN
# 2                     NaN               NaN                 NaN
# 3                     NaN               NaN                 NaN
# 4                     NaN               NaN                 NaN
# 5                     NaN               NaN                 NaN
# ..                    ...               ...                 ...
# 116                   NaN               NaN                 NaN
# 117                   NaN               NaN                 NaN
# 118  #CrisisCommunication             #GIGA               #DSLS
# 119                   NaN               NaN                 NaN
# 120      #localgovernance  #localgovernment  #torymismanagement
#
#     hashtag_related 5           author                         create_at
# 0                 NaN           strike         2023-10-06 11:52:06+00:00
# 2                 NaN  politico_eu_bot  2023-09-16 09:34:38.494000+00:00
# 3                 NaN  politico_eu_bot  2023-09-10 17:33:43.008000+00:00
# 4                 NaN  politico_eu_bot  2023-09-10 15:13:45.314000+00:00
# 5                 NaN  politico_eu_bot  2023-09-10 08:53:43.432000+00:00
# ..                ...              ...                               ...
# 116               NaN  politico_eu_bot  2023-10-04 14:37:58.488000+00:00
# 117               NaN  politico_eu_bot  2023-10-04 14:27:57.169000+00:00
# 118         #DigiTraL   GIGA_Institute         2023-10-04 08:39:17+00:00
# 119               NaN  politico_eu_bot  2023-10-04 02:07:40.570000+00:00
# 120       #ukpolitics     larleywilson         2023-02-25 09:17:03+00:00
#
# [89 rows x 10 columns]
